# %%
from pathlib import Path

# %%
from docling.document_converter import DocumentConverter

# %%
source_paths = [
    Path("bns2023.pdf")
]

converter = DocumentConverter()
results = converter.convert_all(source_paths)

for result in results:
    markdown_output = result.document.export_to_markdown()
    print(f"Processed: {result.input.file.name}")
    output_filename = result.input.file.with_suffix(".md")
    with open(output_filename, "w", encoding="utf-8") as f:
        f.write(markdown_output)
    print(f"File saved as: {output_filename}")
# Out:
# [INFO] 2026-01-17 03:30:16,739 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-17 03:30:16,740 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-17 03:30:16,776 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\HP\.conda\envs\nlp_env\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-17 03:30:16,777 [RapidOCR] main.py:50: Using C:\Users\HP\.conda\envs\nlp_env\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-17 03:30:17,013 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-17 03:30:17,015 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-17 03:30:17,019 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\HP\.conda\envs\nlp_env\Lib\site-packages\rapidocr\models\ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-17 03:30:17,019 [RapidOCR] main.py:50: Using C:\Users\HP\.conda\envs\nlp_env\Lib\site-packages\rapidocr\models\ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-17 03:30:17,148 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-17 03:30:17,150 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-17 03:30:17,195 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\HP\.conda\envs\nlp_env\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-17 03:30:17,197 [RapidOCR] main.py:50: Using C:\Users\HP\.conda\envs\nlp_env\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.pth
# Processed: bns2023.pdf
# File saved as: bns2023.md

# %%
import torch
print(f"Is CUDA available? {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Using GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Is CUDA available? False
